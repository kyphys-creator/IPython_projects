# %%
import numpy as np
T = [[3, 1], [5, 2]]
x = T[0]
x
# Out:
# [3, 1]

# %%
x[1]
# Out:
# 1

# %%
x_np = [0, 1, 2, 3, 4, 5]
print(x_np)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(-10, 10)

plt.plot(x, np.sin(x), "-o", color = "blue", alpha = 0.4)
plt.plot()
# Out:
# []
